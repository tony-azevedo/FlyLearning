# %% [markdown]
# # Import

# %%
from scipy.io import loadmat
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from mapd import Trial, Table
import h5py

import plotly.express as px
import matplotlib.colors as mcolors
# import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.figure import Figure
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)  # reset to defaults
mpl.rcParams['pdf.fonttype'] = 42         # embed fonts as text, not paths
mpl.rcParams['svg.fonttype'] = 'none'     # keep text editable in SVG
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 11


# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %% [markdown]
# # Figure 2

# %% [markdown]
# ## 31H05 dim cell

# %%
T = Table('LEDFlashTriggerPiezoControl_241115_F1_C1_Table.parquet',fig_folder='./RPPR_figures')
# T.open_notes_files()

# %%
T.plot_outcomes(savefig=True)
probe_position_hm_df = T.plot_probe_position_heatmap(savefig=True,cmin=-500,cmax=10)

# %%
T.plot_some_trials(index=T.df.loc[368:373].index,format='svg')
# T.loc[83:85]
# T._excluded_df.loc[84, 'Trial'].plot_probe_groups(use_full_y = True,savefig=False)
# T.df.loc[328, 'Trial'].plot_probe_groups(from_zero=True,use_full_y=False,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[352:353].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[317:319].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[314:316].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[288:290].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[450:451].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[460:461].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[467:468].index,format='svg')

# %%
T.plot_some_trials(index=T.df.loc[467:468].index,format='svg')

# %% [markdown]
# ## 31H05 bright cell

# %%
T = Table('LEDFlashTriggerPiezoControl_240430_F1_C1_Table.parquet',fig_folder='./RPPR_figures')
# T.open_notes_files()

# %%
T.plot_outcomes(savefig=True)
probe_position_hm_df = T.plot_probe_position_heatmap(savefig=True,cmin=-500,cmax=10)

# %%
plt.close()

# %% [markdown]
# # Figure 3

# %% [markdown]
# # Figure 4

# %% [markdown]
# ## 241219_F1_C1 - w;iav-gal4;uas-kir2.1

# %%
T = Table('LEDFlashTriggerPiezoControl_241219_F1_C1_Table.parquet',fig_folder='./RPPR_figures')

# %%
tr_0 = 100

for tr_i in range(tr_0,tr_0+50,5):
    T.plot_some_probe_groups(index=T.df.loc[tr_i:tr_i+5].index,savefig=False)

# %% [markdown]
# ## 241205_F2_C1 - w;iav-gal4;uas-kir2.1

# %%
T = Table('LEDFlashTriggerPiezoControl_241205_F3_C1_Table.parquet','./RPPR_figures')
# T.open_notes_files()
# T.df.Trial[364].plot_probe_groups(format='png')
# T.df.Trial[364].exclude()
# T.exclude_trials()
# T.add_df_category('cut',trial_min=365,categories='_vnc_status_cat')
T.plot_outcomes(savefig=True)

# %%
probe_position_hm_df = T.plot_probe_position_heatmap(savefig=True)

# %%
# tr_0 = 150

# for tr_i in range(tr_0,tr_0+50,5):
#     T.plot_some_probe_groups(index=T.df.loc[tr_i:tr_i+5].index,savefig=False)

# %% [markdown]
# ## 241205_F3_C1 - w;iav-gal4;uas-kir2.1

# %%
T = Table('LEDFlashTriggerPiezoControl_241205_F3_C1_Table.parquet','./RPPR_figures')
# T.open_notes_files()
# T.df.Trial[364].plot_probe_groups(format='png')
# T.df.Trial[364].exclude()
# T.exclude_trials()
# T.add_df_category('cut',trial_min=365,categories='_vnc_status_cat')
T.plot_outcomes(savefig=True)
# Out:
# T = pd.read_parquet("D:\\Data\\241205\\241205_F3_C1\\LEDFlashTriggerPiezoControl_241205_F3_C1_Table.parquet")
# Getting trials
# Pandas Apply:   0%|          | 0/520 [00:00<?, ?it/s]
# Excluding trials:
# [Trial(trial=15, 241205_F3_C1, dT=9.91922, ex=True), Trial(trial=16, 241205_F3_C1, dT=10.64318, ex=True), Trial(trial=17, 241205_F3_C1, dT=10.97324, ex=True), Trial(trial=18, 241205_F3_C1, dT=10.5859, ex=True), Trial(trial=224, 241205_F3_C1, dT=15.48428, ex=True), Trial(trial=225, 241205_F3_C1, dT=14.02702, ex=True)]
# 4 of 4 timeouts (100.0%) during blue light
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
probe_position_hm_df = T.plot_probe_position_heatmap(savefig=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %%
T.plot_some_probe_groups(index=T.df.loc[170:180].index,savefig=True,from_zero=True,format='svg')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tr_0 = 150

for tr_i in range(tr_0,tr_0+50,5):
    T.plot_some_probe_groups(index=T.df.loc[tr_i:tr_i+5].index,savefig=False)

# %%
tr_0 = 300

for tr_i in range(tr_0,tr_0+50,5):
    T.plot_some_probe_groups(index=T.df.loc[tr_i:tr_i+5].index,savefig=False)

# %% [markdown]
# ## 241205_F3_C1 - w;iav-gal4;uas-kir2.1

# %%
# T = Table('LEDFlashTriggerPiezoControl_250320_F1_C1_Table.parquet','./RPPR_figures')
# T.open_notes_files()
# T.df.Trial[364].plot_probe_groups(format='png')
# T.df.Trial[364].exclude()
# T.exclude_trials()
# T.add_df_category('cut',trial_min=365,categories='_vnc_status_cat')
T.extract_trial_properties()
fig,ax = T.plot_outcomes(savefig=True)
display(fig)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# 8
# 50 of 50 timeouts (100.0%) during blue light

# %%
fig,ax,hdmf = T.plot_probe_position_heatmap()
display(fig)

# %%
ftrfig = Figure(figsize=(12,4))
# plt.figure(figsize=(5,5))
ftrax = ftrfig.add_subplot(1, 1, 1)

ax = T.plot_some_probe_groups(index=T.df.loc[329:342].index,ax=ftrax,savefig=False,from_zero=True,format='svg')
display(ftrfig)
ftrfig.savefig(f'./Figure3/iav_example_{T.dfc}_326_342.svg')

# %%
tr_0 = 150

for tr_i in range(tr_0,tr_0+50,5):
    T.plot_some_probe_groups(index=T.df.loc[tr_i:tr_i+5].index,savefig=False)

# %%
tr_0 = 300

for tr_i in range(tr_0,tr_0+50,5):
    T.plot_some_probe_groups(index=T.df.loc[tr_i:tr_i+5].index,savefig=False)
