# %%
from scipy.io import loadmat
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from mapd import Trial, Table, Sinq
import h5py

from matplotlib.figure import Figure
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

def refresh_table_addons():
    import importlib
    import mapd.table_plotters as tps
    import mapd.table_scalars as tbs
    importlib.reload(tps)
    importlib.reload(tbs)

    for name in dir(tps):
        if name.startswith('_'):
            continue
        attr = getattr(tps, name)
        setattr(Table, name[len("plot_"):], attr)
    
    for name in dir(tbs):
        
        if name.startswith('_'):
            continue
        if name.startswith('compute_'):
            attr = getattr(tbs, name)
            setattr(Table, name[len("compute_"):], attr)

# %% [markdown]
# # Create sinq

# %%
sinq1 = Sinq(sinqname='Figure1')
print(sinq1.__repr__())

# %% [markdown]
# # Create Figure 1 control sinq

# %%
sinq = Sinq(sinqname='Fig1_control')
print(sinq.__repr__())
sinq.df

# %%
# cols2add = sinq1.df.columns[~sinq1.df.columns.isin(sinq.df.columns)]
# # cols2add = sinq1.df.columns.difference(sinq.df.columns)
# cols2add
# # 2. Add them to sinq.df with pd.NA
# for col in cols2add:
#     sinq.df[col] = np.nan

# %%
# sinq.sync()

# %% [markdown]
# # Constant 1 s stim.

# %% [markdown]
# ## 251103_F1_C1

# %%
id = '251103_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251103_F2_C1

# %%
id = '251103_F2_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %%
# T.extract_trial_properties()
# T.df.loc[T.df.as_duration == 0,'is_rest']
# fig,ax = T.plot_some_probe_groups(index=T.df.loc[45:49].index)
# display(fig)

# fig = Figure(figsize=(6, 6), dpi=200)
# ax = fig.add_subplot(111)

# T.plot_some_probe_groups(index=T.df.loc[45:49].index,ax=ax) #,force_pos=True)
# display(fig)
# fig.savefig(f'./Figure2/250304_F3_C1/long_sequences/trial_1262.svg')

# %% [markdown]
# ## 251107_F1_C1

# %%
id = '251107_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251107_F2_C1

# %%
id = '251107_F2_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# # Replay

# %% [markdown]
# ## 251113_F1_C1

# %%
id = '251113_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251113_F2_C1

# %%
id = '251113_F2_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251126_F1_C1

# %%
id = '251126_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251203_F1_C1

# %%
id = '251203_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251203_F2_C1

# %%
id = '251203_F2_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251205_F1_C1

# %%
id = '251205_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %% [markdown]
# ## 251205_F2_C1

# %%
id = '251205_F2_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 id = '251205_F2_C1'
# ----> 2 if id in sinq.df.index:
#       3     T = sinq.restore_table(dayflycell=id,overwrite=True)
#       4     # endofdaytrials = T.df.loc[1081:]
#       5     # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
#       6 else:
#
# NameError: name 'sinq' is not defined

# %% [markdown]
# # No probe feedback

# %% [markdown]
# ## 251124_F1_C1

# %%
id = '251124_F1_C1'
if id in sinq.df.index:
    T = sinq.restore_table(dayflycell=id,overwrite=True)
    # endofdaytrials = T.df.loc[1081:]
    # T.exclude_list_of_trials(endofdaytrials.index,reason='tired, frustrated poor behavior')
else:
    T = Table(f'LEDFlashTriggerPiezoControl_{id}_Table.parquet')
    T.assign_column_value('filtercube_status','blue',trial_min=1, write_to_hdf5=True)
    T.assign_column_value('fiberLED','epi_only',trial_min =1,write_to_hdf5=True)
    sinq.add_table(table=T)
    sinq.df
T.exclude_trials()
T.extract_trial_properties()
T.find_successful_trials()
fig,ax = T.plot_outcomes(savefig=True,format='png')
fig,ax,df = T.plot_probe_position_heatmap(cmin=-500,cmax=10,format='png')

# %%
sinq.df
